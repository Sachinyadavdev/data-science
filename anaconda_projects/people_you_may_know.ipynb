# %%
import json

def load_data(filename):
  with open (filename,'r') as f:
    return json.load(f)

def find_people_you_may_know(user_id,data):
    user_friends = {}
    for user in data['users']:
        user_friends[user['id']] = set(user['friends'])

    if user_id not in user_friends:
        return []

    direct_friends = user_friends[user_id]
    suggestions ={}
    for friend in direct_friends:
        for mutual in user_friends[friend]:
            if mutual != user_id and mutual not in direct_friends:
                suggestions[mutual] = suggestions.get(mutual, 0) +1
    sorted_suggestions = sorted(suggestions.items(), key = lambda x: x[1], reverse=True)

    return [user_id for user_id, _ in sorted_suggestions]
          

    

# Load Data 
data = load_data('data.json')

user_id = 7

recommendations = find_people_you_may_know(user_id, data)

print(f"Peopel you may know for the user ID {user_id}: {recommendations}")

print(data)
# Out:
# Peopel you may know for the user ID 7: [1, 2]
# {'users': [{'id': 1, 'name': 'Amit', 'friends': [2, 3], 'liked_pages': [101]}, {'id': 2, 'name': 'Priya', 'friends': [1, 4], 'liked_pages': [102]}, {'id': 3, 'name': '', 'friends': [1], 'liked_pages': [101, 103]}, {'id': 4, 'name': 'Sara', 'friends': [2, 2], 'liked_pages': [104]}, {'id': 5, 'name': 'Amit', 'friends': [], 'liked_pages': []}, {'id': 6, 'name': 'Rahul', 'friends': [1, 2], 'liked_pages': [101, 102]}, {'id': 7, 'name': 'Sneha', 'friends': [3, 4, 10], 'liked_pages': [103, 104]}, {'id': 8, 'name': 'Vikram', 'friends': [1, 4, 11], 'liked_pages': [101, 103]}, {'id': 9, 'name': 'Kavya', 'friends': [2, 4], 'liked_pages': [102, 104]}, {'id': 10, 'name': 'Raj', 'friends': [1, 4], 'liked_pages': [101, 104]}, {'id': 11, 'name': 'Kiran', 'friends': [2, 4], 'liked_pages': [102, 104]}, {'id': 12, 'name': 'Ananya', 'friends': [1, 4], 'liked_pages': [101, 104]}, {'id': 13, 'name': 'Rohan', 'friends': [2, 4], 'liked_pages': [102, 104]}, {'id': 14, 'name': 'Pooja', 'friends': [1, 4], 'liked_pages': [101, 104]}, {'id': 15, 'name': 'Arjun', 'friends': [2, 4], 'liked_pages': [102, 104]}], 'pages': [{'id': 101, 'name': 'Python Developers'}, {'id': 102, 'name': 'Data Science Enthusiasts'}, {'id': 103, 'name': 'AI & ML Community'}, {'id': 104, 'name': 'Web Dev Hub'}, {'id': 104, 'name': 'Web Development'}]}
