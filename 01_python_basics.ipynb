# %%
a =2

# %%
b = 3

# %%
a + b
# Out:
# 5

# %%
name = "Sachin"

# %%
name
# Out:
# 'Sachin'

# %%
name.upper()
# Out:
# 'SACHIN'

# %%
text_in = input("Add the text - ")
# Out:
# Add the text -  hh

# %%
text_in
# Out:
# 'hh'

# %%
code = 560

# %%
match code:
    case 56:
        print("Code Matched")
    case 89:
        print("Code Matched")
    case _:
        print("Nothing Found")
# Out:
# Nothing Found

# %%
import json

# %%
class Employee:
    company = "HP"
    def __init__(self, name, salary):
       self.name =name
       self.salary = salary

    def print_info(self):
        print(f"The company of {self.name} is {self.company} and the salary of the person is {self.salary}")

    @staticmethod
    def print_name():
        print(f"Company name is {name}")

    @classmethod
    def printClassDetail(cls):
        print(f"The company name is {cls.company}")

emp = Employee("Sachin",48000)
emp.print_info()
emp.print_name()
# Out:
# The company of Sachin is HP and the salary of the person is 48000
# Company name is Sachin

# %%
cude = lambda x :x*x*x

# %%
cude(3)
# Out:
# 27

# %%
cude(9)
# Out:
# 729

# %%
def sum():
    a = 8+10
    return

# %% [markdown]
# # Done
